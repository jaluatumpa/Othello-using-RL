# %% [markdown]
# ## Training case 1- Two constant player play against each other

# %%
import othello_withdecay_NN

player1 = DQNAgent(1,n=6,eps_decay=False, start_exp_rate=0.2, end_exp_rate=0.02)
player2 = DQNAgent(-1,n=6,eps_decay=False, start_exp_rate=0.2, end_exp_rate=0.02)
print(player1.exp_rate,player2.exp_rate)

player1 = DQNAgent(1,n=6, eps_decay = False, start_exp_rate=0.2, end_exp_rate=0.02)
player2=DQNAgent(-1,n=6,eps_decay=False,start_exp_rate=0.2,end_exp_rate=0.02)
board=Board(player1,player2,n=6)
board.NNPlay(rounds=1000,name_exp="CP1_CP2")
# Out:
# 0.2 0.2
# training...
# Rounds 0
# length of buffer is 16
# length of buffer is 16
# length of buffer is 137
# length of buffer is 140
# length of buffer is 136
# length of buffer is 138
# length of buffer is 140
# length of buffer is 146
# length of buffer is 130
# length of buffer is 127
# length of buffer is 141
# length of buffer is 143
# length of buffer is 140
# length of buffer is 143
# length of buffer is 136
# length of buffer is 135
# length of buffer is 139
# length of buffer is 139
# length of buffer is 122
# length of buffer is 122
# Rounds 100
# length of buffer is 137
# length of buffer is 137
# length of buffer is 143
# length of buffer is 135
# length of buffer is 131
# length of buffer is 133
# length of buffer is 138
# length of buffer is 144
# length of buffer is 147
# length of buffer is 148
# length of buffer is 146
# length of buffer is 142
# length of buffer is 145
# length of buffer is 141
# length of buffer is 143
# length of buffer is 151
# length of buffer is 127
# length of buffer is 122
# length of buffer is 142
# length of buffer is 142
# Rounds 200
# length of buffer is 130
# length of buffer is 126
# length of buffer is 143
# length of buffer is 145
# length of buffer is 140
# length of buffer is 145
# length of buffer is 131
# length of buffer is 135
# length of buffer is 128
# length of buffer is 134
# length of buffer is 127
# length of buffer is 134
# length of buffer is 150
# length of buffer is 147
# length of buffer is 130
# length of buffer is 132
# length of buffer is 136
# length of buffer is 129
# length of buffer is 146
# length of buffer is 136
# Rounds 300
# length of buffer is 142
# length of buffer is 146
# length of buffer is 141
# length of buffer is 137
# length of buffer is 144
# length of buffer is 150
# length of buffer is 141
# length of buffer is 146
# length of buffer is 137
# length of buffer is 142
# length of buffer is 135
# length of buffer is 127
# length of buffer is 137
# length of buffer is 137
# length of buffer is 133
# length of buffer is 128
# length of buffer is 135
# length of buffer is 129
# length of buffer is 129
# length of buffer is 130
# Rounds 400
# length of buffer is 138
# length of buffer is 139
# length of buffer is 144
# length of buffer is 144
# length of buffer is 139
# length of buffer is 141
# length of buffer is 132
# length of buffer is 129
# length of buffer is 145
# length of buffer is 144
# length of buffer is 140
# length of buffer is 140
# length of buffer is 138
# length of buffer is 139
# length of buffer is 130
# length of buffer is 131
# length of buffer is 136
# length of buffer is 141
# length of buffer is 151
# length of buffer is 148
# Rounds 500
# length of buffer is 132
# length of buffer is 133
# length of buffer is 143
# length of buffer is 139
# length of buffer is 148
# length of buffer is 143
# length of buffer is 137
# length of buffer is 136
# length of buffer is 137
# length of buffer is 139
# length of buffer is 138
# length of buffer is 140
# length of buffer is 139
# length of buffer is 132
# length of buffer is 142
# length of buffer is 141
# length of buffer is 137
# length of buffer is 142
# length of buffer is 131
# length of buffer is 133
# Rounds 600
# length of buffer is 139
# length of buffer is 136
# length of buffer is 134
# length of buffer is 134
# length of buffer is 135
# length of buffer is 136
# length of buffer is 134
# length of buffer is 135
# length of buffer is 124
# length of buffer is 117
# length of buffer is 132
# length of buffer is 134
# length of buffer is 129
# length of buffer is 137
# length of buffer is 135
# length of buffer is 130
# length of buffer is 135
# length of buffer is 135
# length of buffer is 119
# length of buffer is 129
# Rounds 700
# length of buffer is 131
# length of buffer is 134
# length of buffer is 137
# length of buffer is 137
# length of buffer is 146
# length of buffer is 152
# length of buffer is 144
# length of buffer is 138
# length of buffer is 139
# length of buffer is 148
# length of buffer is 128
# length of buffer is 132
# length of buffer is 133
# length of buffer is 136
# length of buffer is 140
# length of buffer is 143
# length of buffer is 146
# length of buffer is 145
# length of buffer is 143
# length of buffer is 140
# Rounds 800
# length of buffer is 132
# length of buffer is 127
# length of buffer is 146
# length of buffer is 138
# length of buffer is 126
# length of buffer is 124
# length of buffer is 148
# length of buffer is 142
# length of buffer is 138
# length of buffer is 142
# length of buffer is 134
# length of buffer is 134
# length of buffer is 134
# length of buffer is 139
# length of buffer is 133
# length of buffer is 134
# length of buffer is 137
# length of buffer is 140
# length of buffer is 143
# length of buffer is 140
# Rounds 900
# length of buffer is 135
# length of buffer is 127
# length of buffer is 144
# length of buffer is 141
# length of buffer is 133
# length of buffer is 144
# length of buffer is 132
# length of buffer is 140
# length of buffer is 137
# length of buffer is 140
# length of buffer is 127
# length of buffer is 135
# length of buffer is 136
# length of buffer is 138
# length of buffer is 139
# length of buffer is 147
# length of buffer is 142
# length of buffer is 143
# length of buffer is 138
# length of buffer is 139

# %% [markdown]
# ## Training case 2 - One is decay player play against  other constant player

# %%
import othello_withdecay_NN

player1 = DQNAgent(1,n=6,eps_decay=False, start_exp_rate=0.2, end_exp_rate=0.02)
player2 = DQNAgent(-1,n=6,eps_decay=False, start_exp_rate=0.2, end_exp_rate=0.02)
print(player1.exp_rate,player2.exp_rate)

player1 = DQNAgent(1,n=6,eps_decay=True, start_exp_rate=0.2, end_exp_rate=0.02)
player2 = DQNAgent(-1,n=6,eps_decay=False, start_exp_rate=0.2, end_exp_rate=0.02)
board=Board(player1,player2,n=6)
board.NNPlay(rounds=1000,name_exp="DP1_CP2")
# Out:
# 0.2 0.2
# training...
# Rounds 0
# decay rate modified at 0 with current value of 0.2
# length of buffer is 17
# length of buffer is 15
# decay rate modified at 10 with current value of 0.19820000000000002
# length of buffer is 146
# length of buffer is 144
# decay rate modified at 20 with current value of 0.19640000000000002
# length of buffer is 146
# length of buffer is 148
# decay rate modified at 30 with current value of 0.1946
# length of buffer is 139
# length of buffer is 139
# decay rate modified at 40 with current value of 0.1928
# length of buffer is 134
# length of buffer is 142
# decay rate modified at 50 with current value of 0.191
# length of buffer is 147
# length of buffer is 146
# decay rate modified at 60 with current value of 0.1892
# length of buffer is 133
# length of buffer is 131
# decay rate modified at 70 with current value of 0.1874
# length of buffer is 151
# length of buffer is 147
# decay rate modified at 80 with current value of 0.18560000000000001
# length of buffer is 124
# length of buffer is 129
# decay rate modified at 90 with current value of 0.18380000000000002
# length of buffer is 138
# length of buffer is 136
# Rounds 100
# decay rate modified at 100 with current value of 0.18200000000000002
# length of buffer is 138
# length of buffer is 136
# decay rate modified at 110 with current value of 0.18020000000000003
# length of buffer is 144
# length of buffer is 152
# decay rate modified at 120 with current value of 0.17840000000000003
# length of buffer is 129
# length of buffer is 131
# decay rate modified at 130 with current value of 0.1766
# length of buffer is 142
# length of buffer is 144
# decay rate modified at 140 with current value of 0.1748
# length of buffer is 132
# length of buffer is 136
# decay rate modified at 150 with current value of 0.17300000000000001
# length of buffer is 140
# length of buffer is 146
# decay rate modified at 160 with current value of 0.17120000000000002
# length of buffer is 136
# length of buffer is 136
# decay rate modified at 170 with current value of 0.1694
# length of buffer is 138
# length of buffer is 134
# decay rate modified at 180 with current value of 0.16760000000000003
# length of buffer is 122
# length of buffer is 127
# decay rate modified at 190 with current value of 0.16580000000000003
# length of buffer is 141
# length of buffer is 145
# Rounds 200
# decay rate modified at 200 with current value of 0.16400000000000003
# length of buffer is 130
# length of buffer is 128
# decay rate modified at 210 with current value of 0.16220000000000004
# length of buffer is 140
# length of buffer is 143
# decay rate modified at 220 with current value of 0.16040000000000001
# length of buffer is 138
# length of buffer is 143
# decay rate modified at 230 with current value of 0.15860000000000002
# length of buffer is 146
# length of buffer is 138
# decay rate modified at 240 with current value of 0.15680000000000002
# length of buffer is 131
# length of buffer is 136
# decay rate modified at 250 with current value of 0.15500000000000003
# length of buffer is 139
# length of buffer is 145
# decay rate modified at 260 with current value of 0.1532
# length of buffer is 140
# length of buffer is 142
# decay rate modified at 270 with current value of 0.15139999999999998
# length of buffer is 126
# length of buffer is 119
# decay rate modified at 280 with current value of 0.14959999999999998
# length of buffer is 141
# length of buffer is 138
# decay rate modified at 290 with current value of 0.1478
# length of buffer is 147
# length of buffer is 136
# Rounds 300
# decay rate modified at 300 with current value of 0.146
# length of buffer is 139
# length of buffer is 139
# decay rate modified at 310 with current value of 0.1442
# length of buffer is 142
# length of buffer is 149
# decay rate modified at 320 with current value of 0.14239999999999997
# length of buffer is 143
# length of buffer is 144
# decay rate modified at 330 with current value of 0.14059999999999997
# length of buffer is 126
# length of buffer is 122
# decay rate modified at 340 with current value of 0.13879999999999998
# length of buffer is 131
# length of buffer is 127
# decay rate modified at 350 with current value of 0.137
# length of buffer is 134
# length of buffer is 136
# decay rate modified at 360 with current value of 0.13520000000000001
# length of buffer is 135
# length of buffer is 138
# decay rate modified at 370 with current value of 0.1334
# length of buffer is 140
# length of buffer is 142
# decay rate modified at 380 with current value of 0.1316
# length of buffer is 133
# length of buffer is 134
# decay rate modified at 390 with current value of 0.1298
# length of buffer is 138
# length of buffer is 141
# Rounds 400
# decay rate modified at 400 with current value of 0.128
# length of buffer is 144
# length of buffer is 146
# decay rate modified at 410 with current value of 0.12620000000000003
# length of buffer is 115
# length of buffer is 113
# decay rate modified at 420 with current value of 0.12440000000000002
# length of buffer is 121
# length of buffer is 120
# decay rate modified at 430 with current value of 0.12260000000000001
# length of buffer is 146
# length of buffer is 136
# decay rate modified at 440 with current value of 0.12080000000000002
# length of buffer is 136
# length of buffer is 126
# decay rate modified at 450 with current value of 0.11900000000000002
# length of buffer is 127
# length of buffer is 126
# decay rate modified at 460 with current value of 0.11720000000000001
# length of buffer is 128
# length of buffer is 132
# decay rate modified at 470 with current value of 0.11540000000000002
# length of buffer is 130
# length of buffer is 135
# decay rate modified at 480 with current value of 0.1136
# length of buffer is 149
# length of buffer is 142
# decay rate modified at 490 with current value of 0.11180000000000001
# length of buffer is 123
# length of buffer is 123
# Rounds 500
# decay rate modified at 500 with current value of 0.11
# length of buffer is 141
# length of buffer is 140
# decay rate modified at 510 with current value of 0.1082
# length of buffer is 132
# length of buffer is 131
# decay rate modified at 520 with current value of 0.10640000000000001
# length of buffer is 110
# length of buffer is 118
# decay rate modified at 530 with current value of 0.1046
# length of buffer is 134
# length of buffer is 123
# decay rate modified at 540 with current value of 0.1028
# length of buffer is 141
# length of buffer is 147
# decay rate modified at 550 with current value of 0.10099999999999999
# length of buffer is 127
# length of buffer is 129
# decay rate modified at 560 with current value of 0.0992
# length of buffer is 137
# length of buffer is 146
# decay rate modified at 570 with current value of 0.09740000000000001
# length of buffer is 122
# length of buffer is 124
# decay rate modified at 580 with current value of 0.09560000000000002
# length of buffer is 133
# length of buffer is 138
# decay rate modified at 590 with current value of 0.09380000000000002
# length of buffer is 139
# length of buffer is 136
# Rounds 600
# decay rate modified at 600 with current value of 0.09200000000000001
# length of buffer is 127
# length of buffer is 133
# decay rate modified at 610 with current value of 0.09020000000000002
# length of buffer is 124
# length of buffer is 122
# decay rate modified at 620 with current value of 0.0884
# length of buffer is 112
# length of buffer is 119
# decay rate modified at 630 with current value of 0.0866
# length of buffer is 109
# length of buffer is 117
# decay rate modified at 640 with current value of 0.0848
# length of buffer is 123
# length of buffer is 133
# decay rate modified at 650 with current value of 0.08299999999999999
# length of buffer is 120
# length of buffer is 119
# decay rate modified at 660 with current value of 0.0812
# length of buffer is 111
# length of buffer is 120
# decay rate modified at 670 with current value of 0.07939999999999998
# length of buffer is 140
# length of buffer is 136
# decay rate modified at 680 with current value of 0.07759999999999999
# length of buffer is 136
# length of buffer is 137
# decay rate modified at 690 with current value of 0.0758
# length of buffer is 107
# length of buffer is 110
# Rounds 700
# decay rate modified at 700 with current value of 0.07400000000000001
# length of buffer is 121
# length of buffer is 126
# decay rate modified at 710 with current value of 0.07220000000000001
# length of buffer is 113
# length of buffer is 123
# decay rate modified at 720 with current value of 0.0704
# length of buffer is 135
# length of buffer is 133
# decay rate modified at 730 with current value of 0.06860000000000001
# length of buffer is 115
# length of buffer is 109
# decay rate modified at 740 with current value of 0.0668
# length of buffer is 115
# length of buffer is 120
# decay rate modified at 750 with current value of 0.065
# length of buffer is 131
# length of buffer is 136
# decay rate modified at 760 with current value of 0.0632
# length of buffer is 124
# length of buffer is 123
# decay rate modified at 770 with current value of 0.061399999999999996
# length of buffer is 112
# length of buffer is 109
# decay rate modified at 780 with current value of 0.0596
# length of buffer is 117
# length of buffer is 116
# decay rate modified at 790 with current value of 0.0578
# length of buffer is 121
# length of buffer is 125
# Rounds 800
# decay rate modified at 800 with current value of 0.055999999999999994
# length of buffer is 81
# length of buffer is 81
# decay rate modified at 810 with current value of 0.0542
# length of buffer is 108
# length of buffer is 120
# decay rate modified at 820 with current value of 0.05240000000000001
# length of buffer is 125
# length of buffer is 131
# decay rate modified at 830 with current value of 0.050600000000000006
# length of buffer is 124
# length of buffer is 131
# decay rate modified at 840 with current value of 0.04880000000000001
# length of buffer is 119
# length of buffer is 126
# decay rate modified at 850 with current value of 0.04700000000000001
# length of buffer is 130
# length of buffer is 140
# decay rate modified at 860 with current value of 0.045200000000000004
# length of buffer is 134
# length of buffer is 127
# decay rate modified at 870 with current value of 0.0434
# length of buffer is 132
# length of buffer is 133
# decay rate modified at 880 with current value of 0.0416
# length of buffer is 110
# length of buffer is 107
# decay rate modified at 890 with current value of 0.0398
# length of buffer is 128
# length of buffer is 136
# Rounds 900
# decay rate modified at 900 with current value of 0.038
# length of buffer is 134
# length of buffer is 136
# decay rate modified at 910 with current value of 0.036199999999999996
# length of buffer is 109
# length of buffer is 109
# decay rate modified at 920 with current value of 0.03439999999999999
# length of buffer is 113
# length of buffer is 117
# decay rate modified at 930 with current value of 0.03259999999999999
# length of buffer is 131
# length of buffer is 139
# decay rate modified at 940 with current value of 0.03080000000000001
# length of buffer is 127
# length of buffer is 125
# decay rate modified at 950 with current value of 0.02900000000000001
# length of buffer is 129
# length of buffer is 131
# decay rate modified at 960 with current value of 0.027200000000000005
# length of buffer is 122
# length of buffer is 117
# decay rate modified at 970 with current value of 0.025400000000000006
# length of buffer is 103
# length of buffer is 108
# decay rate modified at 980 with current value of 0.023600000000000003
# length of buffer is 113
# length of buffer is 114
# decay rate modified at 990 with current value of 0.021800000000000003
# length of buffer is 126
# length of buffer is 134

# %% [markdown]
# ## Training case 2 - Both player are decay

# %%
import othello_withdecay_NN_

player1 = DQNAgent(1,n=6,eps_decay=True, start_exp_rate=0.2, end_exp_rate=0.02)
player2 = DQNAgent(-1,n=6,eps_decay=False, start_exp_rate=0.2, end_exp_rate=0.02)
board=Board(player1,player2,n=6)
board.NNPlay(rounds=1000,name_exp="DP1_CP2")
# Out:
# training...
# Rounds 0
# decay rate modified at 0 with current value of 0.2
# decay rate modified at 0 with current value of 0.2
# length of buffer is 16
# length of buffer is 16
# decay rate modified at 10 with current value of 0.19820000000000002
# decay rate modified at 10 with current value of 0.19820000000000002
# length of buffer is 142
# length of buffer is 141
# decay rate modified at 20 with current value of 0.19640000000000002
# decay rate modified at 20 with current value of 0.19640000000000002
# length of buffer is 138
# length of buffer is 131
# decay rate modified at 30 with current value of 0.1946
# decay rate modified at 30 with current value of 0.1946
# length of buffer is 121
# length of buffer is 122
# decay rate modified at 40 with current value of 0.1928
# decay rate modified at 40 with current value of 0.1928
# length of buffer is 121
# length of buffer is 130
# decay rate modified at 50 with current value of 0.191
# decay rate modified at 50 with current value of 0.191
# length of buffer is 134
# length of buffer is 143
# decay rate modified at 60 with current value of 0.1892
# decay rate modified at 60 with current value of 0.1892
# length of buffer is 138
# length of buffer is 145
# decay rate modified at 70 with current value of 0.1874
# decay rate modified at 70 with current value of 0.1874
# length of buffer is 127
# length of buffer is 127
# decay rate modified at 80 with current value of 0.18560000000000001
# decay rate modified at 80 with current value of 0.18560000000000001
# length of buffer is 130
# length of buffer is 129
# decay rate modified at 90 with current value of 0.18380000000000002
# decay rate modified at 90 with current value of 0.18380000000000002
# length of buffer is 131
# length of buffer is 133
# Rounds 100
# decay rate modified at 100 with current value of 0.18200000000000002
# decay rate modified at 100 with current value of 0.18200000000000002
# length of buffer is 140
# length of buffer is 134
# decay rate modified at 110 with current value of 0.18020000000000003
# decay rate modified at 110 with current value of 0.18020000000000003
# length of buffer is 135
# length of buffer is 134
# decay rate modified at 120 with current value of 0.17840000000000003
# decay rate modified at 120 with current value of 0.17840000000000003
# length of buffer is 135
# length of buffer is 127
# decay rate modified at 130 with current value of 0.1766
# decay rate modified at 130 with current value of 0.1766
# length of buffer is 148
# length of buffer is 144
# decay rate modified at 140 with current value of 0.1748
# decay rate modified at 140 with current value of 0.1748
# length of buffer is 127
# length of buffer is 127
# decay rate modified at 150 with current value of 0.17300000000000001
# decay rate modified at 150 with current value of 0.17300000000000001
# length of buffer is 142
# length of buffer is 133
# decay rate modified at 160 with current value of 0.17120000000000002
# decay rate modified at 160 with current value of 0.17120000000000002
# length of buffer is 142
# length of buffer is 140
# decay rate modified at 170 with current value of 0.1694
# decay rate modified at 170 with current value of 0.1694
# length of buffer is 128
# length of buffer is 131
# decay rate modified at 180 with current value of 0.16760000000000003
# decay rate modified at 180 with current value of 0.16760000000000003
# length of buffer is 141
# length of buffer is 142
# decay rate modified at 190 with current value of 0.16580000000000003
# decay rate modified at 190 with current value of 0.16580000000000003
# length of buffer is 131
# length of buffer is 128
# Rounds 200
# decay rate modified at 200 with current value of 0.16400000000000003
# decay rate modified at 200 with current value of 0.16400000000000003
# length of buffer is 134
# length of buffer is 128
# decay rate modified at 210 with current value of 0.16220000000000004
# decay rate modified at 210 with current value of 0.16220000000000004
# length of buffer is 137
# length of buffer is 142
# decay rate modified at 220 with current value of 0.16040000000000001
# decay rate modified at 220 with current value of 0.16040000000000001
# length of buffer is 138
# length of buffer is 143
# decay rate modified at 230 with current value of 0.15860000000000002
# decay rate modified at 230 with current value of 0.15860000000000002
# length of buffer is 141
# length of buffer is 141
# decay rate modified at 240 with current value of 0.15680000000000002
# decay rate modified at 240 with current value of 0.15680000000000002
# length of buffer is 132
# length of buffer is 136
# decay rate modified at 250 with current value of 0.15500000000000003
# decay rate modified at 250 with current value of 0.15500000000000003
# length of buffer is 120
# length of buffer is 118
# decay rate modified at 260 with current value of 0.1532
# decay rate modified at 260 with current value of 0.1532
# length of buffer is 134
# length of buffer is 146
# decay rate modified at 270 with current value of 0.15139999999999998
# decay rate modified at 270 with current value of 0.15139999999999998
# length of buffer is 133
# length of buffer is 141
# decay rate modified at 280 with current value of 0.14959999999999998
# decay rate modified at 280 with current value of 0.14959999999999998
# length of buffer is 140
# length of buffer is 134
# decay rate modified at 290 with current value of 0.1478
# decay rate modified at 290 with current value of 0.1478
# length of buffer is 140
# length of buffer is 137
# Rounds 300
# decay rate modified at 300 with current value of 0.146
# decay rate modified at 300 with current value of 0.146
# length of buffer is 121
# length of buffer is 110
# decay rate modified at 310 with current value of 0.1442
# decay rate modified at 310 with current value of 0.1442
# length of buffer is 121
# length of buffer is 127
# decay rate modified at 320 with current value of 0.14239999999999997
# decay rate modified at 320 with current value of 0.14239999999999997
# length of buffer is 123
# length of buffer is 132
# decay rate modified at 330 with current value of 0.14059999999999997
# decay rate modified at 330 with current value of 0.14059999999999997
# length of buffer is 138
# length of buffer is 141
# decay rate modified at 340 with current value of 0.13879999999999998
# decay rate modified at 340 with current value of 0.13879999999999998
# length of buffer is 140
# length of buffer is 135
# decay rate modified at 350 with current value of 0.137
# decay rate modified at 350 with current value of 0.137
# length of buffer is 104
# length of buffer is 104
# decay rate modified at 360 with current value of 0.13520000000000001
# decay rate modified at 360 with current value of 0.13520000000000001
# length of buffer is 136
# length of buffer is 136
# decay rate modified at 370 with current value of 0.1334
# decay rate modified at 370 with current value of 0.1334
# length of buffer is 144
# length of buffer is 146
# decay rate modified at 380 with current value of 0.1316
# decay rate modified at 380 with current value of 0.1316
# length of buffer is 128
# length of buffer is 134
# decay rate modified at 390 with current value of 0.1298
# decay rate modified at 390 with current value of 0.1298
# length of buffer is 126
# length of buffer is 128
# Rounds 400
# decay rate modified at 400 with current value of 0.128
# decay rate modified at 400 with current value of 0.128
# length of buffer is 137
# length of buffer is 132
# decay rate modified at 410 with current value of 0.12620000000000003
# decay rate modified at 410 with current value of 0.12620000000000003
# length of buffer is 131
# length of buffer is 139
# decay rate modified at 420 with current value of 0.12440000000000002
# decay rate modified at 420 with current value of 0.12440000000000002
# length of buffer is 115
# length of buffer is 113
# decay rate modified at 430 with current value of 0.12260000000000001
# decay rate modified at 430 with current value of 0.12260000000000001
# length of buffer is 131
# length of buffer is 127
# decay rate modified at 440 with current value of 0.12080000000000002
# decay rate modified at 440 with current value of 0.12080000000000002
# length of buffer is 129
# length of buffer is 119
# decay rate modified at 450 with current value of 0.11900000000000002
# decay rate modified at 450 with current value of 0.11900000000000002
# length of buffer is 106
# length of buffer is 96
# decay rate modified at 460 with current value of 0.11720000000000001
# decay rate modified at 460 with current value of 0.11720000000000001
# length of buffer is 103
# length of buffer is 102
# decay rate modified at 470 with current value of 0.11540000000000002
# decay rate modified at 470 with current value of 0.11540000000000002
# length of buffer is 126
# length of buffer is 123
# decay rate modified at 480 with current value of 0.1136
# decay rate modified at 480 with current value of 0.1136
# length of buffer is 131
# length of buffer is 129
# decay rate modified at 490 with current value of 0.11180000000000001
# decay rate modified at 490 with current value of 0.11180000000000001
# length of buffer is 108
# length of buffer is 116
# Rounds 500
# decay rate modified at 500 with current value of 0.11
# decay rate modified at 500 with current value of 0.11
# length of buffer is 99
# length of buffer is 111
# decay rate modified at 510 with current value of 0.1082
# decay rate modified at 510 with current value of 0.1082
# length of buffer is 135
# length of buffer is 128
# decay rate modified at 520 with current value of 0.10640000000000001
# decay rate modified at 520 with current value of 0.10640000000000001
# length of buffer is 109
# length of buffer is 111
# decay rate modified at 530 with current value of 0.1046
# decay rate modified at 530 with current value of 0.1046
# length of buffer is 100
# length of buffer is 108
# decay rate modified at 540 with current value of 0.1028
# decay rate modified at 540 with current value of 0.1028
# length of buffer is 123
# length of buffer is 127
# decay rate modified at 550 with current value of 0.10099999999999999
# decay rate modified at 550 with current value of 0.10099999999999999
# length of buffer is 125
# length of buffer is 127
# decay rate modified at 560 with current value of 0.0992
# decay rate modified at 560 with current value of 0.0992
# length of buffer is 135
# length of buffer is 132
# decay rate modified at 570 with current value of 0.09740000000000001
# decay rate modified at 570 with current value of 0.09740000000000001
# length of buffer is 124
# length of buffer is 126
# decay rate modified at 580 with current value of 0.09560000000000002
# decay rate modified at 580 with current value of 0.09560000000000002
# length of buffer is 123
# length of buffer is 120
# decay rate modified at 590 with current value of 0.09380000000000002
# decay rate modified at 590 with current value of 0.09380000000000002
# length of buffer is 97
# length of buffer is 92
# Rounds 600
# decay rate modified at 600 with current value of 0.09200000000000001
# decay rate modified at 600 with current value of 0.09200000000000001
# length of buffer is 116
# length of buffer is 117
# decay rate modified at 610 with current value of 0.09020000000000002
# decay rate modified at 610 with current value of 0.09020000000000002
# length of buffer is 124
# length of buffer is 125
# decay rate modified at 620 with current value of 0.0884
# decay rate modified at 620 with current value of 0.0884
# length of buffer is 121
# length of buffer is 114
# decay rate modified at 630 with current value of 0.0866
# decay rate modified at 630 with current value of 0.0866
# length of buffer is 107
# length of buffer is 100
# decay rate modified at 640 with current value of 0.0848
# decay rate modified at 640 with current value of 0.0848
# length of buffer is 95
# length of buffer is 97
# decay rate modified at 650 with current value of 0.08299999999999999
# decay rate modified at 650 with current value of 0.08299999999999999
# length of buffer is 126
# length of buffer is 128
# decay rate modified at 660 with current value of 0.0812
# decay rate modified at 660 with current value of 0.0812
# length of buffer is 55
# length of buffer is 44
# decay rate modified at 670 with current value of 0.07939999999999998
# decay rate modified at 670 with current value of 0.07939999999999998
# length of buffer is 98
# length of buffer is 104
# decay rate modified at 680 with current value of 0.07759999999999999
# decay rate modified at 680 with current value of 0.07759999999999999
# length of buffer is 73
# length of buffer is 79
# decay rate modified at 690 with current value of 0.0758
# decay rate modified at 690 with current value of 0.0758
# length of buffer is 107
# length of buffer is 107
# Rounds 700
# decay rate modified at 700 with current value of 0.07400000000000001
# decay rate modified at 700 with current value of 0.07400000000000001
# length of buffer is 111
# length of buffer is 109
# decay rate modified at 710 with current value of 0.07220000000000001
# decay rate modified at 710 with current value of 0.07220000000000001
# length of buffer is 121
# length of buffer is 122
# decay rate modified at 720 with current value of 0.0704
# decay rate modified at 720 with current value of 0.0704
# length of buffer is 67
# length of buffer is 76
# decay rate modified at 730 with current value of 0.06860000000000001
# decay rate modified at 730 with current value of 0.06860000000000001
# length of buffer is 63
# length of buffer is 71
# decay rate modified at 740 with current value of 0.0668
# decay rate modified at 740 with current value of 0.0668
# length of buffer is 109
# length of buffer is 112
# decay rate modified at 750 with current value of 0.065
# decay rate modified at 750 with current value of 0.065
# length of buffer is 107
# length of buffer is 109
# decay rate modified at 760 with current value of 0.0632
# decay rate modified at 760 with current value of 0.0632
# length of buffer is 81
# length of buffer is 74
# decay rate modified at 770 with current value of 0.061399999999999996
# decay rate modified at 770 with current value of 0.061399999999999996
# length of buffer is 102
# length of buffer is 99
# decay rate modified at 780 with current value of 0.0596
# decay rate modified at 780 with current value of 0.0596
# length of buffer is 102
# length of buffer is 98
# decay rate modified at 790 with current value of 0.0578
# decay rate modified at 790 with current value of 0.0578
# length of buffer is 85
# length of buffer is 97
# Rounds 800
# decay rate modified at 800 with current value of 0.055999999999999994
# decay rate modified at 800 with current value of 0.055999999999999994
# length of buffer is 83
# length of buffer is 79
# decay rate modified at 810 with current value of 0.0542
# decay rate modified at 810 with current value of 0.0542
# length of buffer is 83
# length of buffer is 90
# decay rate modified at 820 with current value of 0.05240000000000001
# decay rate modified at 820 with current value of 0.05240000000000001
# length of buffer is 111
# length of buffer is 114
# decay rate modified at 830 with current value of 0.050600000000000006
# decay rate modified at 830 with current value of 0.050600000000000006
# length of buffer is 82
# length of buffer is 87
# decay rate modified at 840 with current value of 0.04880000000000001
# decay rate modified at 840 with current value of 0.04880000000000001
# length of buffer is 95
# length of buffer is 98
# decay rate modified at 850 with current value of 0.04700000000000001
# decay rate modified at 850 with current value of 0.04700000000000001
# length of buffer is 91
# length of buffer is 95
# decay rate modified at 860 with current value of 0.045200000000000004
# decay rate modified at 860 with current value of 0.045200000000000004
# length of buffer is 79
# length of buffer is 80
# decay rate modified at 870 with current value of 0.0434
# decay rate modified at 870 with current value of 0.0434
# length of buffer is 47
# length of buffer is 53
# decay rate modified at 880 with current value of 0.0416
# decay rate modified at 880 with current value of 0.0416
# length of buffer is 113
# length of buffer is 110
# decay rate modified at 890 with current value of 0.0398
# decay rate modified at 890 with current value of 0.0398
# length of buffer is 75
# length of buffer is 80
# Rounds 900
# decay rate modified at 900 with current value of 0.038
# decay rate modified at 900 with current value of 0.038
# length of buffer is 104
# length of buffer is 112
# decay rate modified at 910 with current value of 0.036199999999999996
# decay rate modified at 910 with current value of 0.036199999999999996
# length of buffer is 69
# length of buffer is 78
# decay rate modified at 920 with current value of 0.03439999999999999
# decay rate modified at 920 with current value of 0.03439999999999999
# length of buffer is 40
# length of buffer is 42
# decay rate modified at 930 with current value of 0.03259999999999999
# decay rate modified at 930 with current value of 0.03259999999999999
# length of buffer is 67
# length of buffer is 66
# decay rate modified at 940 with current value of 0.03080000000000001
# decay rate modified at 940 with current value of 0.03080000000000001
# length of buffer is 54
# length of buffer is 61
# decay rate modified at 950 with current value of 0.02900000000000001
# decay rate modified at 950 with current value of 0.02900000000000001
# length of buffer is 56
# length of buffer is 50
# decay rate modified at 960 with current value of 0.027200000000000005
# decay rate modified at 960 with current value of 0.027200000000000005
# length of buffer is 57
# length of buffer is 60
# decay rate modified at 970 with current value of 0.025400000000000006
# decay rate modified at 970 with current value of 0.025400000000000006
# length of buffer is 23
# length of buffer is 29
# decay rate modified at 980 with current value of 0.023600000000000003
# decay rate modified at 980 with current value of 0.023600000000000003
# length of buffer is 55
# length of buffer is 57
# decay rate modified at 990 with current value of 0.021800000000000003
# decay rate modified at 990 with current value of 0.021800000000000003
# length of buffer is 80
# length of buffer is 83
